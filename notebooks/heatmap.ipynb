# %%
from urllib.request import urlopen
import json
import os

import numpy as np
import pandas as pd

import csv
# import plotly.express as px
# import plotly.graph_objects as go  # or plotly.express as px

# from .about_us import about_us_html

# %%
def county2fips_fct(x):
    if x in county2fips:
        return str(int(county2fips[x]))
    else:
        return np.nan


# # define data dir
data_dir = "../data"
data_filepath = data_dir
# data_filepath = os.path.join(os.path.dirname(os.path.realpath(__file__)), data_dir)

counties_with_latlong = pd.read_csv(
    os.path.join(data_filepath, "counties.txt"), dtype={"GEOID": str}, sep="\t"
)

# get sundown town data
df = pd.read_csv(os.path.join(data_filepath, "sundown_with_counties.csv"), encoding="latin-1")
df["County_no_states"] = df.county.str.split(",").apply(lambda x: x[0])
county_long_names = []
for i in df.county.values:
    x = i.split(",")
    if len(x) == 2:
        county_long_names.append(x[0] + " " + x[1])
    else:
        county_long_names.append(x)
df["county_long_names"] = county_long_names

# get fips data
fips_codes = pd.read_csv(os.path.join(data_filepath, "county_fips_master.csv"), encoding="latin-1")
county2fips = dict(fips_codes[["county_name", "fips"]].values)

# %%
county_sundown_counts = pd.DataFrame(df.groupby(by="County_no_states").size())
county_sundown_counts = county_sundown_counts.reset_index()
county_sundown_counts = county_sundown_counts.rename(columns={"County_no_states": "County", 0: "#"})
county_sundown_counts["fips"] = county_sundown_counts.County.apply(lambda x: county2fips_fct(x))
county_sundown_counts = county_sundown_counts[county_sundown_counts.fips.notnull()]

with urlopen(
    "https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json"
) as response:
    counties = json.load(response)

df = pd.read_csv(
    "https://raw.githubusercontent.com/plotly/datasets/master/fips-unemp-16.csv",
    dtype={"fips": str},
)

tab_style = {
    "borderBottom": "1px solid #d6d6d6",
    "padding": "6px",
    "margin-bottom": "10px",
    "fontWeight": "bold",
}

tab_selected_style = {
    "borderTop": "1px solid #d6d6d6",
    "borderBottom": "1px solid #d6d6d6",
    "padding": "6px",
    "margin-bottom": "10px",
}

# %%
counties_with_latlong = pd.read_csv('../data/counties.txt', dtype={"GEOID": str}, sep='\t', skipinitialspace=True)

# %%
counties_with_latlong.USPS.unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'PR'], dtype=object)

# %%
city_county_dict = dict()
with open('../data/us_cities_to_county.csv') as city_mapping_file:
    city_mapping_reader = csv.DictReader(city_mapping_file)
    for c in city_mapping_reader:
        # need to add in state, otherwise get missed mappings
        city_county_dict[(c['city'] + ' ' + c['state_id']).lower()] = c['county_name']

# %%
import pandas as pd

sundown_data = {}
with open('../data/sundown_states.csv') as sundown_file:
    city_reader = csv.DictReader(sundown_file)
    for r in city_reader:
        city_state = r['city'] + ' ' + r['state']
        if city_state.lower() in city_county_dict.keys():
            data = r
            data['county'] = city_county_dict[city_state.lower()] + ' County' +', ' + r['state']
            sundown_data[r['id']] = data
        elif 'County' in r['city']:
            print('missed mapping: {}'.format(r['city']))
            data['county'] = r['city']
            sundown_data[r['id']] = data
# Out:
# missed mapping: Buchanan County
# missed mapping: Pulaski County
# missed mapping: Taylor County
# missed mapping: Clay County
# missed mapping: Newton County
# missed mapping: Cleburne County
# missed mapping: Scott County
# missed mapping: Stone County
# missed mapping: Spink County
# missed mapping: Orange County
# missed mapping: Wheeler County
# missed mapping: Comanche County
# missed mapping: Hamilton County
# missed mapping: Montague County
# missed mapping: Marion County
# missed mapping: Del Norte County
# missed mapping: Cullman County
# missed mapping: Antelope County
# missed mapping: Burt County
# missed mapping: Butler County
# missed mapping: Cass County
# missed mapping: Cedar County
# missed mapping: Cheyenne County
# missed mapping: Humboldt County
# missed mapping: Dallam County
# missed mapping: Scurry County
# missed mapping: Mitchell County
# missed mapping: Graham County
# missed mapping: Forsyth County
# missed mapping: Menominee County
# missed mapping: Greer County
# missed mapping: Ottawa County
# missed mapping: Swain County
# missed mapping: Cherokee County
# missed mapping: Dawson County
# missed mapping: Banks County
# missed mapping: Gilmer County
# missed mapping: Towns County
# missed mapping: Union County
# missed mapping: Murray County
# missed mapping: Pickens County
# missed mapping: Rabun County
# missed mapping: Thomas County
# missed mapping: Fulton County
# missed mapping: Hancock County
# missed mapping: Howard County
# missed mapping: Carbon County
# missed mapping: Lincoln County
# missed mapping: Barnes County
# missed mapping: Emmons County
# missed mapping: LaMoure County
# missed mapping: McLean County
# missed mapping: Rolette County
# missed mapping: Traill County
# missed mapping: Calvert County
# missed mapping: Garrett County
# missed mapping: Union County
# missed mapping: McHenry County
# missed mapping: Kane County
# missed mapping: Calhoun County
# missed mapping: Brown County
# missed mapping: Baxter County
# missed mapping: Winston County
# missed mapping: Crawford County
# missed mapping: Clinton County
# missed mapping: DuPage County
# missed mapping: Throckmorton County
# missed mapping: Piatt County
# missed mapping: Jasper County
# missed mapping: Monroe County
# missed mapping: Perry County
# missed mapping: Ochiltree County
# missed mapping: Haskell County
# missed mapping: Comanche County
# missed mapping: Cheyenne County
# missed mapping: Elk County
# missed mapping: Gove County
# missed mapping: Greeley County
# missed mapping: Kiowa County
# missed mapping: Lane County
# missed mapping: Lincoln County
# missed mapping: Morton County
# missed mapping: Ness County
# missed mapping: Wichita County
# missed mapping: Rawlins County
# missed mapping: Sherman County
# missed mapping: Mitchell County
# missed mapping: Republic County
# missed mapping: Decatur County
# missed mapping: McPherson County
# missed mapping: Woodson County
# missed mapping: Seward County
# missed mapping: Arthur County
# missed mapping: Banner County
# missed mapping: Chase County
# missed mapping: Cuming County
# missed mapping: Deuel County
# missed mapping: Dixon County
# missed mapping: Dundy County
# missed mapping: Franklin County
# missed mapping: Garden County
# missed mapping: Garfield County
# missed mapping: Gosper County
# missed mapping: Hayes County
# missed mapping: Hooker County
# missed mapping: Johnson County
# missed mapping: Marshall County
# missed mapping: Kearney County
# missed mapping: Loup County
# missed mapping: McPherson County
# missed mapping: Nance County
# missed mapping: Colfax County
# missed mapping: Greeley County
# missed mapping: Keith County
# missed mapping: Platte County
# missed mapping: Seward County
# missed mapping: Logan County
# missed mapping: Saunders County
# missed mapping: Nuckolls County
# missed mapping: Dawson County
# missed mapping: Harlan County
# missed mapping: Nemaha County
# missed mapping: Sheridan County
# missed mapping: Merrick County
# missed mapping: Sarpy County
# missed mapping: York County
# missed mapping: Cherry County
# missed mapping: Lincoln County
# missed mapping: Madison County
# missed mapping: Red Willow County
# missed mapping: Dawes County
# missed mapping: Richardson County
# missed mapping: Otoe County
# missed mapping: Buffalo County
# missed mapping: Dodge County
# missed mapping: Gage County
# missed mapping: Adams County
# missed mapping: Hall County
# missed mapping: Lancaster County
# missed mapping: Douglas County
# missed mapping: Grant County
# missed mapping: Perkins County
# missed mapping: Rock County
# missed mapping: Thomas County
# missed mapping: Valley County
# missed mapping: Frontier County
# missed mapping: Hitchcock County
# missed mapping: Kimball County
# missed mapping: Pierce County
# missed mapping: Blaine County
# missed mapping: Furnas County
# missed mapping: Brown County
# missed mapping: Pawnee County
# missed mapping: Phelps County
# missed mapping: Wayne County
# missed mapping: Boyd County
# missed mapping: Sherman County
# missed mapping: Howard County
# missed mapping: Boone County
# missed mapping: Sioux County
# missed mapping: Stanton County
# missed mapping: Webster County
# missed mapping: Thayer County
# missed mapping: Polk County
# missed mapping: Clay County
# missed mapping: Fillmore County
# missed mapping: Keya Paha County
# missed mapping: Holt County
# missed mapping: Knox County
# missed mapping: Morrill County
# missed mapping: Hamilton County
# missed mapping: Wheeler County
# missed mapping: Saline County
# missed mapping: Armstrong County
# missed mapping: Briscoe County
# missed mapping: Carson County
# missed mapping: Castro County
# missed mapping: Childress County
# missed mapping: Collingsworth County
# missed mapping: Deaf Smith County
# missed mapping: Donley County
# missed mapping: Gray County
# missed mapping: Hall County
# missed mapping: Hansford County
# missed mapping: Hartley County
# missed mapping: Hemphill County
# missed mapping: Hutchinson County
# missed mapping: Lipscomb County
# missed mapping: Moore County
# missed mapping: Oldham County
# missed mapping: Parmer County
# missed mapping: Potter County
# missed mapping: Randall County
# missed mapping: Roberts County
# missed mapping: Sherman County
# missed mapping: Swisher County
# missed mapping: Sheridan County
# missed mapping: Stanton County
# missed mapping: Rush County
# missed mapping: Clark County
# missed mapping: Thomas County
# missed mapping: Kearney County
# missed mapping: Gray County
# missed mapping: Stevens County
# missed mapping: Logan County
# missed mapping: Barber County
# missed mapping: Cloud County
# missed mapping: Wallace County
# missed mapping: Trego County
# missed mapping: Ford County
# missed mapping: Hamilton County
# missed mapping: Rooks County
# missed mapping: Finney County
# missed mapping: Ellis County
# missed mapping: Ottawa County
# missed mapping: Edwards County
# missed mapping: Butler County
# missed mapping: Osborne County
# missed mapping: Rice County
# missed mapping: Ellsworth County
# missed mapping: Pawnee County
# missed mapping: Hodgeman County
# missed mapping: Dickinson County
# missed mapping: Phillips County
# missed mapping: Greenwood County
# missed mapping: Sumner County
# missed mapping: Chase County
# missed mapping: Pratt County
# missed mapping: Coffey County
# missed mapping: Lincoln County
# missed mapping: York County
# missed mapping: Westchester County

# %%
sundown_with_counties_df = pd.DataFrame(sundown_data.values())
sundown_with_counties_df.to_csv('../data/sundown_with_counties.csv')

# %%
sundown_with_counties_df
# Out:
#         id              city state                  status  \
# 0        8              Anna    IL                  Surely
# 1       11              Mize    MS                  Surely
# 2       13       d'Iberville    MS                Possible
# 3       14           Clinton    MS                Unlikely
# 4       15             Pearl    MS                Possible
# 5       16         Southaven    MS                Possible
# 6       17        Burnsville    MS                Probable
# 7       18           Belmont    MS                Possible
# 8       18           Belmont    MS                Possible
# 9       20  Colonial Heights    VA                Probable
# 10      21         Inglewood    CA                  Surely
# 11      22         Hawthorne    CA                  Surely
# 12      23           Chester    WV                Probable
# 13      24        Follansbee    WV                Probable
# 14      25            Kenova    WV                Possible
# 2255         Cleveland County, OK
# 2256         Cleveland County, OK
# 2257             Union County, NJ
#
# [2258 rows x 5 columns]

# %%
# unique values of sundown towns
sundown_with_counties_df['status'].unique()
# Out:
# array(['Surely', 'Possible', 'Unlikely', 'Probable',
#        'Black Town or Township', "Don't Know", 'Always Biracial', ''],
#       dtype=object)

# %%
counties_with_latlong.columns = map(lambda s:s.strip(), counties_with_latlong.columns)

# %%
matching_state = counties_with_latlong[counties_with_latlong["USPS"] == 'AL']

# %%
matching_state.INTPTLONG
# Out:
# 0    -86.646440
# 1    -87.746067
# 2    -85.405104
# 3    -87.127148
# 4    -86.566440
# 5    -85.717261
# 6    -86.681969
# 7    -85.827909
# 8    -85.394032
# 9    -85.654242
# 10   -86.726607
# 11   -88.248889
# 12   -87.818624
# 13   -85.863525
# 14   -85.516126
# 15   -85.989602
# 16   -87.801457
# 17   -86.988722
# 18   -86.243482
# 19   -86.448721
# 20   -86.319222
# 21   -86.869267
# 22   -85.609476
# 23   -87.114356
# 24   -85.803992
# 25   -86.142735
# 26   -87.168410
# 27   -86.034263
# 28   -87.764292
# 29   -87.842814
#         ...
# 37   -88.087431
# 38   -87.650997
# 39   -87.321865
# 40   -85.353048
# 41   -86.981399
# 42   -86.650586
# 43   -85.692887
# 44   -86.551080
# 45   -87.791091
# 46   -87.881551
# 47   -86.321668
# 48   -88.196568
# 49   -87.383266
# 50   -86.204461
# 51   -86.846402
# 52   -87.293827
# 53   -88.096863
# 54   -85.941604
# 55   -85.464068
# 56   -85.186980
# 57   -86.315663
# 58   -86.678089
# 59   -88.200057
# 60   -86.175930
# 61   -85.799618
# 62   -87.522783
# 63   -87.301094
# 64   -88.197564
# 65   -87.304935
# 66   -87.365346
# Name: INTPTLONG, Length: 67, dtype: float64

# %%
latlon = matching_state[matching_state.columns[-2:]].values.tolist()[0]

# %%
matching_state
# Out:
#    USPS  GEOID  ANSICODE               NAME       ALAND      AWATER  \
# 0    AL  01001    161526     Autauga County  1539602137    25706961
# 1    AL  01003    161527     Baldwin County  4117621645  1132980868
# 2    AL  01005    161528     Barbour County  2292160139    50523213
# 3    AL  01007    161529        Bibb County  1612167476     9602089
# 4    AL  01009    161530      Blount County  1670103866    15015467
# 5    AL  01011    161531     Bullock County  1613076054     6038093
# 6    AL  01013    161532      Butler County  2012002531     2701198
# 7    AL  01015    161533     Calhoun County  1569195268    16587192
# 8    AL  01017    161534    Chambers County  1545085607    16971700
# 9    AL  01019    161535    Cherokee County  1433623319   120308342
# 10   AL  01021    161536     Chilton County  1794477075    20592142
# 11   AL  01023    161537     Choctaw County  2365869841    19144469
# 12   AL  01025    161538      Clarke County  3207494106    36657891
# 13   AL  01027    161539        Clay County  1564251834     5285207
# 14   AL  01029    161540    Cleburne County  1450663786     2354896
# 15   AL  01031    161541      Coffee County  1758565919     3907189
# 16   AL  01033    161542     Colbert County  1535202321    79700278
# 17   AL  01035    161543     Conecuh County  2202007855     6632046
# 18   AL  01037    161544       Coosa County  1685850815    39987271
# 19   AL  01039    161545   Covington County  2669134207    34226200
# 20   AL  01041    161546    Crenshaw County  1576952799     5388562
# 21   AL  01043    161547     Cullman County  1902970816    52525039
